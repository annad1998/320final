# %% [markdown]
# Goal Compare property value throughout the years
# - see where most places has people moving in and out (look at number of sales)
# - see which place is most expensive (look at average sell price)
# - see which place is on the rise (look at median sale price)
# - see if we can get data from those years to predict current prices (do regression fit line, year to amount - use median sale)
#
# source file:
# property values - https://catalog.data.gov/dataset?q=Summary+of+Neighborhood+Sales+for+Queens&as_sfid=AAAAAAX1aTcL_dTLlWLD69I2ZrQhG5DeLLi-Rciu0eK3gTdzSTTd9zcm9YypC4hbJTs_BBHFR4LKlxINv8KvGv2thiC3_qaEyhYdozu40X7vkjoxL5wHk8a6gdWOjky49KUKvDg%3D&as_fid=b9d75d678b79b72a1d8bb9d04356231f210c5ac0 (2005-2009)
#
# neighborhood shape files - https://www1.nyc.gov/site/planning/data-maps/open-data/bytes-archive.page?sorts[year]=0&queries[search]=Neighborhood (Neighborhood Tabulation Areas - Shapefile 2020, 20A)

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.8/site-packages (from geopandas) (1.2.2)
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp38-cp38-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 10.5 MB/s eta 0:00:01
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.0.1-cp38-cp38-manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 13.2 MB/s eta 0:00:01
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.19-cp38-cp38-manylinux1_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 13.5 MB/s eta 0:00:01
# Collecting cligj>=0.5
#   Downloading cligj-0.7.1-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (1.20.1)
# Installing collected packages: munch, cligj, click-plugins, shapely, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.19 geopandas-0.9.0 munch-2.5.0 pyproj-3.0.1 shapely-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p2005 = pd.read_csv("./2005.csv")
p2006 = pd.read_csv("./2006.csv")
p2007 = pd.read_csv("./2007.csv")
p2008 = pd.read_csv("./2008.csv")
p2009 = pd.read_csv("./2009.csv")

p2008
# Out:
#                   NEIGHBORHOOD                                 TYPE OF HOME  \
# 0    AIRPORT LA GUARDIA         01 ONE FAMILY HOMES
# 1    AIRPORT LA GUARDIA         02 TWO FAMILY HOMES
# 2    ARVERNE                    01 ONE FAMILY HOMES
# 3    ARVERNE                    02 TWO FAMILY HOMES
# 4    ARVERNE                    03 THREE FAMILY HOMES
# ..                         ...                                          ...
# 150  WOODHAVEN                  02 TWO FAMILY HOMES
# 151  WOODHAVEN                  03 THREE FAMILY HOMES
# 152  WOODSIDE                   01 ONE FAMILY HOMES
# 153  WOODSIDE                   02 TWO FAMILY HOMES
# 154  WOODSIDE                   03 THREE FAMILY HOMES
#
#      NUMBER OF SALES  LOWEST SALE PRICE  AVERAGE SALE PRICE  \
# 0                  1           425000.0            425000.0
# 1                  1           575000.0            575000.0
# 2                 35           150000.0            295315.0
# 3                156           210000.0            513853.0
# 4                  8           286500.0            422919.0
# ..               ...                ...                 ...
# 150              101           200000.0            500715.0
# 151               21           217500.0            483278.0
# 152               27           200664.0            512454.0
# 153               33           200000.0            651098.0
# 154               23           330000.0            770708.0
#
#      MEDIAN SALE PRICE  HIGHEST SALE PRICE
# 0             425000.0            425000.0
# 1             575000.0            575000.0
# 2             273667.0            705000.0
# 3             542337.0            967337.0
# 4             444500.0            525000.0
# ..                 ...                 ...
# 150           508247.0            723500.0
# 151           500000.0            750000.0
# 152           515000.0            900000.0
# 153           633356.0           1350000.0
# 154           780000.0           1250000.0
#
# [155 rows x 7 columns]

# %%
neighborhoods = p2009['NEIGHBORHOOD'].unique()
sales_dict = {}

for n in neighborhoods:
    sales_dict[n] = 0

for i, row in p2005.iterrows():
    if row['NEIGHBORHOOD'] in sales_dict: 
        sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    else:
        sales_dict[row["NEIGHBORHOOD"]] = row["NUMBER OF SALES"]
        
for i, row in p2006.iterrows():
    if row['NEIGHBORHOOD'] in sales_dict: 
        sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    else:
        sales_dict[row["NEIGHBORHOOD"]] = row["NUMBER OF SALES"]

for i, row in p2007.iterrows():
    if row['NEIGHBORHOOD'] in sales_dict: 
        sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    else:
        sales_dict[row["NEIGHBORHOOD"]] = row["NUMBER OF SALES"]
        
for i, row in p2008.iterrows():
    if row['NEIGHBORHOOD'] in sales_dict: 
        sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    else:
        sales_dict[row["NEIGHBORHOOD"]] = row["NUMBER OF SALES"]
        
for i, row in p2009.iterrows():
    if row['NEIGHBORHOOD'] in sales_dict: 
        sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    else:
        sales_dict[row["NEIGHBORHOOD"]] = row["NUMBER OF SALES"]
        
sorted(sales_dict.items(), key=lambda x:x[1])
# Out:
# [('AIRPORT LA GUARDIA       ', 17),
#  ('JAMAICA BAY              ', 52),
#  ('NEPONSIT                 ', 91),
#  ('BROAD CHANNEL            ', 134),
#  ('ROCKAWAY PARK            ', 144),
#  ('GLEN OAKS                ', 148),
#  ('HOLLIS HILLS             ', 156),
#  ('HILLCREST                ', 194),
#  ('HOLLISWOOD               ', 202),
#  ('BEECHHURST               ', 224),
#  ('BRIARWOOD                ', 229),
#  ('HAMMELS                  ', 234),
#  ('BELLE HARBOR             ', 255),
#  ('KEW GARDENS              ', 262),
#  ('LONG ISLAND CITY         ', 266),
#  ('SUNNYSIDE                ', 309),
#  ('JAMAICA ESTATES          ', 336),
#  ('JAMAICA HILLS            ', 352),
#  ('DOUGLASTON               ', 356),
#  ('OAKLAND GARDENS          ', 441),
#  ('FRESH MEADOWS            ', 517),
#  ('REGO PARK                ', 526),
#  ('LITTLE NECK              ', 582),
#  ('WOODSIDE                 ', 608),
#  ('CAMBRIA HEIGHTS          ', 656),
#  ('FLORAL PARK              ', 679),
#  ('HOWARD BEACH             ', 716),
#  ('JAMAICA                  ', 745),
#  ('BELLEROSE                ', 801),
#  ('FOREST HILLS             ', 875),
#  ('RIDGEWOOD                ', 900),
#  ('EAST ELMHURST            ', 1005),
#  ('WHITESTONE               ', 1047),
#  ('GLENDALE                 ', 1078),
#  ('COLLEGE POINT            ', 1161),
#  ('ARVERNE                  ', 1210),
#  ('MASPETH                  ', 1286),
#  ('LAURELTON                ', 1289),
#  ('MIDDLE VILLAGE           ', 1296),
#  ('ASTORIA                  ', 1402),
#  ('FAR ROCKAWAY             ', 1542),
#  ('JACKSON HEIGHTS          ', 1543),
#  ('ELMHURST                 ', 1672),
#  ('FLUSHING-SOUTH           ', 1691),
#  ('WOODHAVEN                ', 1753),
#  ('CORONA                   ', 1787),
#  ('HOLLIS                   ', 1802),
#  ('OZONE PARK               ', 1951),
#  ('ROSEDALE                 ', 2002),
#  ('BAYSIDE                  ', 2227),
#  ('QUEENS VILLAGE           ', 2346),
#  ('SPRINGFIELD GARDENS      ', 2483),
#  ('SOUTH OZONE PARK         ', 2540),
#  ('ST. ALBANS               ', 2584),
#  ('SOUTH JAMAICA            ', 3024),
#  ('RICHMOND HILL            ', 3097),
#  ('SO. JAMAICA-BAISLEY PARK ', 3115),
#  ('FLUSHING-NORTH           ', 4296)]

# %%
nb_data = gpd.read_file("./nynta.shp")

# %%
to_drop = nb_data[nb_data["BoroName"] != "Queens"].index
nb_data.drop(to_drop, inplace=True)
nb_data
# Out:
#      BoroCode BoroName CountyFIPS NTACode  \
# 1           4   Queens        081    QN51
# 2           4   Queens        081    QN27
# 3           4   Queens        081    QN07
# 7           4   Queens        081    QN41
# 8           4   Queens        081    QN08
# 9           4   Queens        081    QN06
# 15          4   Queens        081    QN61
# 16          4   Queens        081    QN01
# 18          4   Queens        081    QN33
# 34          4   Queens        081    QN20
# 37          4   Queens        081    QN68
# 42          4   Queens        081    QN19
# 44          4   Queens        081    QN38
# 46          4   Queens        081    QN34
# 47          4   Queens        081    QN43
# 48          4   Queens        081    QN21
# 49          4   Queens        081    QN29
# 50          4   Queens        081    QN66
# 54          4   Queens        081    QN55
# 57          4   Queens        081    QN30
# 58          4   Queens        081    QN50
# 59          4   Queens        081    QN23
# 67          4   Queens        081    QN54
# 74          4   Queens        081    QN53
# 85          4   Queens        081    QN44
# 86          4   Queens        081    QN45
# 95          4   Queens        081    QN48
# 96          4   Queens        081    QN52
# 114         4   Queens        081    QN10
# 115         4   Queens        081    QN12
# 118         4   Queens        081    QN03
# 119         4   Queens        081    QN05
# 125         4   Queens        081    QN15
# 126         4   Queens        081    QN70
# 135         4   Queens        081    QN46
# 143         4   Queens        081    QN31
# 145         4   Queens        081    QN71
# 147         4   Queens        081    QN72
# 148         4   Queens        081    QN98
# 149         4   Queens        081    QN47
# 154         4   Queens        081    QN22
# 155         4   Queens        081    QN49
# 156         4   Queens        081    QN02
# 157         4   Queens        081    QN76
# 159         4   Queens        081    QN42
# 166         4   Queens        081    QN56
# 167         4   Queens        081    QN57
# 168         4   Queens        081    QN62
# 169         4   Queens        081    QN37
# 170         4   Queens        081    QN99
# 174         4   Queens        081    QN25
# 175         4   Queens        081    QN26
# 183         4   Queens        081    QN17
# 184         4   Queens        081    QN18
# 186         4   Queens        081    QN28
# 187         4   Queens        081    QN63
# 193         4   Queens        081    QN35
# 194         4   Queens        081    QN60
#
#                                                NTAName     Shape_Leng  \
# 1                                          Murray Hill   33266.904797
# 2                                        East Elmhurst   19816.711908
# 3                                               Hollis   20976.335574
# 7                                 Fresh Meadows-Utopia   22106.431272
# 8                                           St. Albans   45401.316949
# 9                           Jamaica Estates-Holliswood   35465.974926
# 15                                             Jamaica   43696.364726
# 16                                       South Jamaica   32122.552357
# 18                                     Cambria Heights   26168.270088
# 34                                           Ridgewood   40608.513200
# 37            Queensbridge-Ravenswood-Long Island City   27067.652867
# 42                                            Glendale   41514.435051
# 44                  Pomonok-Flushing Heights-Hillcrest   30731.592023
# 46                                      Queens Village   41782.401111
# 47                                           Bellerose   32086.150893
# 48                                      Middle Village   42675.548488
# 49                                            Elmhurst   36711.336372
# 50                                           Laurelton   29530.927904
# 54                                    South Ozone Park   36708.169286
# 57                                             Maspeth   41265.643302
# 58                                    Elmhurst-Maspeth   32362.825201
# 59                                       College Point   59454.749417
# 67                                       Richmond Hill   33792.465529
# 74                                           Woodhaven   28067.664472
# 85                 Glen Oaks-Floral Park-New Hyde Park   33596.473160
# 86                Douglas Manor-Douglaston-Little Neck   45784.458090
# 95                                          Auburndale   32452.059674
# 96                                       East Flushing   25848.545418
# 114  Breezy Point-Belle Harbor-Rockaway Park-Broad ...  114095.120021
# 115                           Hammels-Arverne-Edgemere   83804.731304
# 118               Springfield Gardens South-Brookville   45322.123086
# 119                                           Rosedale   64163.723337
# 125                             Far Rockaway-Bayswater   48684.416968
# 126                                            Astoria   32534.738400
# 135                              Bayside-Bayside Hills   43020.787937
# 143               Hunters Point-Sunnyside-West Maspeth   74592.142708
# 145                                        Old Astoria   19366.217019
# 147                                           Steinway   43563.149490
# 148                                            Airport  136232.037351
# 149                   Ft. Totten-Bay Terrace-Clearview   39625.842670
# 154                                           Flushing   38362.728127
# 155                                         Whitestone   62139.047242
# 156                          Springfield Gardens North   25437.061864
# 157                                       Baisley Park   31478.438130
# 159                                    Oakland Gardens   42410.067721
# 166                                         Ozone Park   24731.699084
# 167                            Lindenwood-Howard Beach   79085.799957
# 168                                    Queensboro Hill   30548.654580
# 169                                  Kew Gardens Hills   33105.724129
# 170                           park-cemetery-etc-Queens  490956.063302
# 174                                             Corona   23868.641664
# 175                                       North Corona   18429.540236
# 183                                       Forest Hills   36171.472651
# 184                                          Rego Park   26675.103444
# 186                                    Jackson Heights   29423.561527
# 187                                           Woodside   27869.363232
# 193                            Briarwood-Jamaica Hills   30029.287357
# 194                                        Kew Gardens   21440.868253
#
#        Shape_Area                                           geometry
# 1    5.248828e+07  POLYGON ((1038593.459 221913.355, 1039369.281 ...
# 2    1.972685e+07  POLYGON ((1022728.275 217530.808, 1023052.645 ...
# 3    2.288777e+07  POLYGON ((1051539.660 201007.013, 1051920.726 ...
# 7    2.777485e+07  POLYGON ((1045896.171 205383.934, 1045643.832 ...
# 8    7.741275e+07  POLYGON ((1052996.114 196307.361, 1053081.596 ...
# 9    4.278998e+07  POLYGON ((1051684.884 203955.166, 1051683.111 ...
# 15   4.730804e+07  POLYGON ((1048446.277 197901.245, 1048241.242 ...
# 16   3.997193e+07  POLYGON ((1046927.616 194315.449, 1046788.275 ...
# 18   3.307680e+07  POLYGON ((1060005.735 195538.074, 1060020.410 ...
# 34   5.049518e+07  POLYGON ((1010649.674 199007.086, 1010927.754 ...
# 37   2.331703e+07  POLYGON ((1002384.940 220244.057, 1002462.870 ...
# 42   3.001674e+07  POLYGON ((1023813.126 198515.584, 1023986.077 ...
# 44   3.883596e+07  POLYGON ((1040671.302 208318.344, 1040674.718 ...
# 46   6.953343e+07  POLYGON ((1059599.151 202832.505, 1059506.770 ...
# 47   5.518428e+07  POLYGON ((1064489.883 204357.587, 1064472.458 ...
# 48   5.768491e+07  POLYGON ((1023157.382 199211.229, 1023120.968 ...
# 49   3.267535e+07  POLYGON ((1020851.425 210703.673, 1020860.825 ...
# 50   3.978492e+07  POLYGON ((1053768.826 189186.300, 1054114.297 ...
# 54   8.246139e+07  POLYGON ((1038120.442 188146.832, 1038190.284 ...
# 57   3.563316e+07  POLYGON ((1015144.455 206905.754, 1015156.758 ...
# 58   2.192767e+07  POLYGON ((1014244.431 211378.830, 1014343.991 ...
# 59   5.055398e+07  MULTIPOLYGON (((1020835.195 226161.343, 102079...
# 67   5.097840e+07  POLYGON ((1035162.882 195252.025, 1035229.739 ...
# 74   3.700043e+07  POLYGON ((1026082.094 193715.713, 1025988.075 ...
# 85   4.566694e+07  POLYGON ((1064489.883 204357.587, 1064488.833 ...
# 86   6.839417e+07  POLYGON ((1063614.449 216235.870, 1063408.186 ...
# 95   3.416492e+07  POLYGON ((1046392.971 210169.754, 1046376.695 ...
# 96   2.945368e+07  POLYGON ((1041061.948 215429.461, 1041115.124 ...
# 114  9.943604e+07  MULTIPOLYGON (((1016626.562 146409.869, 101665...
# 115  6.189496e+07  POLYGON ((1048650.082 157173.057, 1048691.041 ...
# 118  4.328849e+07  POLYGON ((1051487.928 182175.542, 1051506.494 ...
# 119  6.156926e+07  POLYGON ((1059828.741 184924.923, 1059759.660 ...
# 125  5.416042e+07  POLYGON ((1049860.789 154842.320, 1049834.381 ...
# 126  3.933551e+07  POLYGON ((1011389.066 218882.567, 1011346.351 ...
# 135  8.079859e+07  POLYGON ((1048560.005 223080.083, 1048613.047 ...
# 143  1.024218e+08  POLYGON ((1004855.956 213309.301, 1005191.106 ...
# 145  1.561960e+07  POLYGON ((1004114.386 222330.201, 1004240.694 ...
# 147  5.772446e+07  POLYGON ((1014209.093 221605.059, 1014622.662 ...
# 148  2.281992e+08  MULTIPOLYGON (((1054434.340 171513.080, 105444...
# 149  4.629259e+07  POLYGON ((1048560.005 223080.083, 1048513.939 ...
# 154  3.786507e+07  POLYGON ((1033183.441 223347.719, 1033119.048 ...
# 155  6.905071e+07  POLYGON ((1041904.434 226927.508, 1041968.085 ...
# 156  2.843265e+07  POLYGON ((1050734.885 185328.134, 1051155.786 ...
# 157  4.403858e+07  POLYGON ((1046740.336 187276.198, 1046724.788 ...
# 159  5.100968e+07  POLYGON ((1056254.319 208432.264, 1055902.161 ...
# 166  2.501684e+07  POLYGON ((1028591.796 187476.975, 1028761.196 ...
# 167  6.455895e+07  MULTIPOLYGON (((1023868.747 176222.723, 102336...
# 168  2.655933e+07  POLYGON ((1035407.183 211562.349, 1035574.302 ...
# 169  3.788836e+07  POLYGON ((1035524.981 208408.343, 1035562.192 ...
# 170  3.116917e+08  MULTIPOLYGON (((1021692.969 147138.664, 102188...
# 174  2.007732e+07  MULTIPOLYGON (((1024585.351 212137.050, 102460...
# 175  1.800389e+07  POLYGON ((1024560.201 215571.542, 1024640.130 ...
# 183  5.782765e+07  POLYGON ((1031091.644 199573.816, 1031058.058 ...
# 184  1.994181e+07  POLYGON ((1023401.945 207346.662, 1023416.928 ...
# 186  4.785850e+07  POLYGON ((1019252.570 215025.859, 1019515.726 ...
# 187  2.824660e+07  POLYGON ((1012323.995 216152.675, 1012213.611 ...
# 193  2.937737e+07  POLYGON ((1041627.321 198275.486, 1041389.733 ...
# 194  2.049257e+07  POLYGON ((1035162.882 195252.025, 1035135.970 ...

# %%
nb_map = nb_data.plot(figsize=(40,20))
for i, row in nb_data.iterrows():
    x = row['geometry'].centroid.x
    y = row['geometry'].centroid.y
    label = nb_data.NTAName
    nb_map.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points")

# for x, y, label in zip(nb_data['geometry'].centriod.x, nb_data['geometry'].centriod.y, nb_data.NTAName):
#     nb_map.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points")
plt.show()

# %%
len(p2009['NEIGHBORHOOD'].unique())
# Out:
# 58
