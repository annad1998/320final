# %% [markdown]
# Goal Compare property value throughout the years
# - see where most places has people moving in and out (look at number of sales)
# - see which place is most expensive (look at average sell price)
# - see which place is on the rise (look at median sale price)
# - see if we can get data from those years to predict current prices (do regression fit line, year to amount - use median sale)
#
# source file:
# property values - https://catalog.data.gov/dataset?q=Summary+of+Neighborhood+Sales+for+Queens&as_sfid=AAAAAAX1aTcL_dTLlWLD69I2ZrQhG5DeLLi-Rciu0eK3gTdzSTTd9zcm9YypC4hbJTs_BBHFR4LKlxINv8KvGv2thiC3_qaEyhYdozu40X7vkjoxL5wHk8a6gdWOjky49KUKvDg%3D&as_fid=b9d75d678b79b72a1d8bb9d04356231f210c5ac0 (2008 and 2009)
#
# neighborhood shape files - https://www1.nyc.gov/site/planning/data-maps/open-data/bytes-archive.page?sorts[year]=0&queries[search]=Neighborhood (Neighborhood Tabulation Areas - Shapefile 2020, 20A)

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 1.9 MB/s eta 0:00:01
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.0.1-cp38-cp38-manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 9.0 MB/s eta 0:00:01
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.19-cp38-cp38-manylinux1_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 9.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.8/site-packages (from geopandas) (1.2.2)
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp38-cp38-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 10.8 MB/s eta 0:00:01
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.1-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (1.20.1)
# Installing collected packages: munch, cligj, click-plugins, shapely, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.19 geopandas-0.9.0 munch-2.5.0 pyproj-3.0.1 shapely-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from bs4 import BeautifulSoup as bs
import requests as re

# %%
p2005 = pd.read_csv("./2005.csv")
p2006 = pd.read_csv("./2006.csv")
p2007 = pd.read_csv("./2007.csv")
p2008 = pd.read_csv("./2008.csv")
p2009 = pd.read_csv("./2009.csv")

# %%
neighborhoods5 = p2005['NEIGHBORHOOD'].unique()
neighborhoods6 = p2006['NEIGHBORHOOD'].unique()
neighborhoods7 = p2007['NEIGHBORHOOD'].unique()
neighborhoods8 = p2008['NEIGHBORHOOD'].unique()
neighborhoods9 = p2009['NEIGHBORHOOD'].unique()

for n in neighborhoods9:
    if n in neighborhoods8 and n in neighborhoods7 and n in neighborhoods6  and n in neighborhoods5:
        continue
    else:
        print(n)

p2005['NEIGHBORHOOD'] = p2005['NEIGHBORHOOD'].str.strip()        
p2006['NEIGHBORHOOD'] = p2006['NEIGHBORHOOD'].str.strip()
p2007['NEIGHBORHOOD'] = p2007['NEIGHBORHOOD'].str.strip()
p2008['NEIGHBORHOOD'] = p2009['NEIGHBORHOOD'].str.strip()
p2009['NEIGHBORHOOD'] = p2009['NEIGHBORHOOD'].str.strip()

sales_dict = {}
average_cost_dict = {}
instance_dict = {}

for n in neighborhoods9:
    sales_dict[n] = 0
    average_cost_dict[n] = 0
    instance_dict[n] = 0
    
for i, row in p2005.iterrows():
    sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    average_cost_dict[row['NEIGHBORHOOD']] += row["AVERAGE SALE PRICE"]

for i, row in p2006.iterrows():
    sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    average_cost_dict[row['NEIGHBORHOOD']] += row["AVERAGE SALE PRICE"]
        
for i, row in p2007.iterrows():
    sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    average_cost_dict[row['NEIGHBORHOOD']] += row["AVERAGE SALE PRICE"]
        
for i, row in p2008.iterrows():
    sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    average_cost_dict[row['NEIGHBORHOOD']] += row["AVERAGE SALE PRICE"]
        
for i, row in p2009.iterrows():
    sales_dict[row['NEIGHBORHOOD']] += row["NUMBER OF SALES"]
    average_cost_dict[row['NEIGHBORHOOD']] += row["AVERAGE SALE PRICE"]

# %%
nb_names = p2009['NEIGHBORHOOD']

for n in nb_names:
    instance_dict[n] += 1
  
for n in average_cost_dict.keys():
    average_cost_dict[n] = average_cost_dict[n] / (instance_dict[n] * 5) #because 2005-2009
    
cost_data = pd.DataFrame(average_cost_dict.items(), columns=['NTAName', 'COST'])

# %%
nb_data = gpd.read_file("./nynta.shp")
to_drop = nb_data[nb_data["BoroName"] != "Queens"].index
nb_data.drop(to_drop, inplace=True)

nb_data = nb_data.drop(columns=["BoroCode", "BoroName", "CountyFIPS", "NTACode", "Shape_Leng", "Shape_Area"])

# %%
nb_data['sales'] = 0

# adding sales data to overall df
for i, row in nb_data.iterrows():
    if row['NTAName'].upper() in sales_dict:
        nb_data.at[i, 'sales'] = sales_dict[row['NTAName'].upper()]
        
nb_map = nb_data.plot(column='sales', k=8, cmap='Blues', figsize=(40,20), linewidth=1, edgecolor='0.5', legend=True)

for i, row in nb_data.iterrows():
    if row['NTAName'].upper() in sales_dict:
        x = row['geometry'].centroid.x
        y = row['geometry'].centroid.y
        label = row['NTAName'] + "\n" + str(row['sales'])
        nb_map.annotate(label, xy=(x, y), xytext=(-25, 0), color="white", textcoords="offset points", fontsize=10, weight="bold")

nb_map.set(title="Neighborhood and Property Sales in Queens, NY")
nb_map.set_axis_off()

# %%
nb_data['cost'] = 0

for i, row in nb_data.iterrows():
    if row['NTAName'].upper() in sales_dict:
        nb_data.at[i, 'cost'] = average_cost_dict[row['NTAName'].upper()]

nb_cost = nb_data.plot(column='cost', k=8, cmap='Reds', figsize=(40,20), linewidth=1, edgecolor='0.5', legend=True)
   
for i, row in nb_data.iterrows():
    if row['NTAName'].upper() in average_cost_dict:
        x = row['geometry'].centroid.x
        y = row['geometry'].centroid.y
        formatter =  "{:,}".format((row['cost']))
        label = row['NTAName'] + "\n" + formatter
        nb_cost.annotate(label, xy=(x, y), xytext=(-25, 0), color="white", textcoords="offset points", fontsize=10, weight="bold")


nb_cost.set(title="Average Cost of Neighborhoods in Queens, NY")
nb_cost.set_axis_off()
        
# nb_data = nb_data.drop(columns=["geometry"])
# format_mapping = {"cost": "${:,.2f}"}
# nb_data.style.format(format_mapping)

# %%
p2005['YEAR'] = 2005
p2006['YEAR'] = 2006
p2007['YEAR'] = 2007
p2008['YEAR'] = 2008
p2009['YEAR'] = 2009

frames = [p2005, p2006, p2007, p2008, p2009]
merged = pd.concat(frames)
merged = merged.drop(columns=["TYPE OF HOME", "NUMBER OF SALES", "LOWEST SALE PRICE", "HIGHEST SALE PRICE", "TOTAL NO. OF PROPERTIES"])

# %%
nb_names = p2009['NEIGHBORHOOD'].unique()
# for i, row in nb_data.iterrows():
#     if row['NTAName'].upper() in nb_names:
#         continue
#     else:
#         nb_data = nb_data.drop(i)
df = merged

nb_data_names = []
temp = nb_data['NTAName'].unique()
for n in temp:
    nb_data_names.append(str(n).upper())

match = []
counter =  0
for n in nb_names:    
    if n in nb_data_names:
        match.append(n)
        locals()['df' + str(counter)] = df[(df.NEIGHBORHOOD == n)]
        counter += 1

# %%
plt_row = 10
plt_col = 3

figure, ax = plt.subplots(nrows=plt_row, ncols=plt_col, figsize=(20,30))
figure.tight_layout(pad=3.0)

average_sales = []
row_counter = 0 
col_counter = 0
for i in range(counter):
    x = locals()['df' + str(i)]['YEAR']
    y = locals()['df' + str(i)]['AVERAGE SALE PRICE']
    ax[row_counter][col_counter].scatter(x, y)
    ax[row_counter][col_counter].title.set_text(match[i])
    m, b = np.polyfit(x, y, 1)
    ax[row_counter][col_counter].plot(x, m * x + b)
    average_sales.append(str(m*2021+b))
    #     print(match[i] + " " + str(m*2021+b))
    
    if col_counter < (plt_col-1):
        col_counter += 1
    else:
        col_counter = 0
        row_counter += 1

# %%
figurey, axy = plt.subplots(nrows=plt_row, ncols=plt_col, figsize=(20,30))
figurey.tight_layout(pad=3.0)

med_sales = []
row_counter = 0 
col_counter = 0
for i in range(counter):
    x = locals()['df' + str(i)]['YEAR']
    y = locals()['df' + str(i)]['MEDIAN SALE PRICE']
    axy[row_counter][col_counter].scatter(x, y)
    axy[row_counter][col_counter].title.set_text(match[i])
    m, b = np.polyfit(x, y, 1)
    axy[row_counter][col_counter].plot(x, m * x + b)
    med_sales.append(str(m*2021+b))
    #     print(match[i] + " " + str(m*2021+b))
   
    if col_counter < (plt_col-1):
        col_counter += 1
    else:
        col_counter = 0
        row_counter += 1

# %%
link = 'https://www.propertyshark.com/mason/market-trends/residential/nyc/queens/'
response = re.get(link)
site = bs(response.text, 'html.parser')
#scraping the data from table @ specified class
table = site.find(id="nyc_nhoods_table");
table


temp = []
counter  = 0
for data in table.find_all('td'):
    
    if data.text != "Queens":
        if "$" in data.text:
            temp.append(data.text[1:])
        else:
            temp.append(data.text.upper())
temp

name_med = {}
med = []

counter = 0
for t in temp:
    if counter % 2 == 0:
        name_med[t] = 0
    else:
        med.append(t)
    counter += 1
    
name_med
# Out:
# {'NEPONSIT': 0,
#  'MALBA': 0,
#  'EAST FLUSHING': 0,
#  'BELLE HARBOR': 0,
#  'QUEENSBORO HILL': 0,
#  'HUNTERS POINT': 0,
#  'FRESH MEADOWS': 0,
#  'HOLLIS HILLS': 0,
#  'AUBURNDALE': 0,
#  'DITMARS - STEINWAY': 0,
#  'ROCKWOOD PARK': 0,
#  'BAYSIDE': 0,
#  'RIDGEWOOD': 0,
#  'EAST ELMHURST': 0,
#  'SOUTH ASTORIA': 0,
#  'MIDDLE VILLAGE': 0,
#  'FLORAL PARK': 0,
#  'OLD HOWARD BEACH': 0,
#  'POMONOK': 0,
#  'DOUGLASTON': 0,
#  'BREEZY POINT': 0,
#  'COLLEGE POINT': 0,
#  'GLENDALE': 0,
#  'WHITESTONE': 0,
#  'MASPETH': 0,
#  'OZONE PARK': 0,
#  'QUEENS VILLAGE': 0,
#  'HOLLIS': 0,
#  'OLD ASTORIA': 0,
#  'RICHMOND HILL': 0,
#  'WOODHAVEN': 0,
#  'ROSEDALE': 0,
#  'BROOKVILLE': 0,
#  'SOUTH OZONE PARK': 0,
#  'CAMBRIA HEIGHTS': 0,
#  'SPRINGFIELD GARDENS': 0,
#  'SEASIDE': 0,
#  'HAMILTON BEACH': 0,
#  'SAINT ALBANS': 0,
#  'LAURELTON': 0,
#  'JAMAICA': 0,
#  'FAR ROCKAWAY': 0,
#  'MURRAY HILL': 0,
#  'ROCHDALE': 0,
#  'ASTORIA HEIGHTS / UPPER DITMARS': 0,
#  'ROCKAWAY BEACH': 0,
#  'BROAD CHANNEL': 0,
#  'LIC': 0,
#  'BAY TERRACE': 0,
#  'ELMHURST': 0,
#  'SUNNYSIDE GARDENS': 0,
#  'FOREST HILLS': 0,
#  'ROXBURY': 0,
#  'DOWNTOWN FLUSHING': 0,
#  'ARVERNE': 0,
#  'SUNNYSIDE': 0,
#  'RAMBLERSVILLE': 0,
#  'WOODSIDE': 0,
#  'BELLEROSE': 0,
#  'JACKSON HEIGHTS': 0,
#  'REGO PARK': 0,
#  'ROCKAWAY PARK': 0,
#  'KEW GARDENS': 0,
#  'GLEN OAKS': 0,
#  'OAKLAND GARDENS': 0,
#  'BRIARWOOD': 0,
#  'EAST NEW YORK': 0,
#  'LINDENWOOD': 0,
#  'CORONA': 0,
#  'KEW GARDENS HILLS': 0,
#  'LITTLE NECK': 0,
#  'JAMAICA HILLS': 0,
#  'JAMAICA ESTATES': 0}
